# %% [markdown]
# <a id='top'></a>
# # Using projects with archives/git

# %%
import mlrun

# %% [markdown]
# <a id='create-project'></a>
# ## Create a new project and registering functions

# %%
project_name = "git-proj"
project = mlrun.new_project(project_name, user_project=True, init_git=True, description="my new project")

# %% [markdown]
# ### Register project functions

# %%
# define a job (batch) function which uses code/libs from the project repo
project.set_function(
    name="ad_model_training", handler="training.train_ad_model",
    image="mlrun/mlrun", kind="job", with_repo=True,
)

# %% [markdown]
# **Register functions by reference (serving graph function example):**

# %%
# define a serving graph function with 3 steps (*2, +3, echo)
serving = mlrun.new_function("ad_model_serving", kind="serving", image="mlrun/mlrun")
graph = serving.set_topology("flow",engine="async")

graph.to(handler="serving.preprocess", name="preprocess")\
     .to(class_name="ModelOnDemandServer", name="model_on_demand_server")\
     .to(handler="serving.postprocess", name="postprocess").respond()

# plot the serving graph
serving.spec.graph.plot(rankdir="LR")

# %%
# save the function definition into a .yaml file and register it in the project
serving.export("ad_model_serving.yaml")
project.set_function("serving.yaml", name="ad_model_serving", with_repo=True)
# Out:
# > 2022-06-29 08:59:42,678 [info] function spec saved to path: ad_model_serving.yaml

# %% [markdown]
# **Register additional project objects and metadata:**

# %%
# save the project in the db (and into the project.yaml file)
project.save()

# %% [markdown]
# see the generated project file: [**project.yaml**](project.yaml)
# ### Push the project code/metadata into an Archive

# %% [markdown]
# <a id='load'></a>
# ## Load a project from local/remote archive
#
# The project metadata and context (code and configuration) can be loaded and initialized using the {py:meth}`~mlrun.projects.load_project` method.
# when `url` (of the git/zip/tar) is specified it clones a remote repo into the local `context` dir.
#
#     # load the project and run the 'main' workflow
#     project = load_project(context="./", name="myproj", url="git://github.com/mlrun/project-archive.git")
#     project.run("main", arguments={'data': data_url})
#
# Projects can also be loaded and executed using the CLI:
#
#     mlrun project -n myproj -u "git://github.com/mlrun/project-archive.git" .
#     mlrun project -r main -w -a data=<data-url> .

# %%
# load the project in the current context dir
project = mlrun.load_project("./")

# %% [markdown]
# <a id='deploy-job'></a>
# ## Deploy and execute job functions
#
# You can execute functions locally for test and debug, just turn on the `local=True` flag

# %%
# run training function
git_source = "https://github.com/vivekcherarajan1992/anomalydetection.git#main"
project.set_source(git_source, pull_at_runtime=True)

import uuid
instanceId=str(uuid.uuid1())

run = project.run_function("ad_model_training",params={'insightpak_name': 'ad_model','instance_id':instanceId}, local=True)
# Out:
# > 2022-06-29 09:00:11,159 [warning] run command, file or code were not specified
# > 2022-06-29 09:00:11,160 [info] starting run ad_model_training-train_ad_model uid=3888d4f600ae4d95a252dca82830b626 DB=http://mlrun-api:8080
# Epoch 1/2
# 4/4 [==============================] - 0s 30ms/step - loss: 3.2439 - accuracy: 0.0847
# Epoch 2/2
# 4/4 [==============================] - 0s 26ms/step - loss: 3.2026 - accuracy: 0.0932
# INFO:tensorflow:Assets written to: ./model/ad_model/assets
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>git-proj-vivek</td>
#       <td><div title="3888d4f600ae4d95a252dca82830b626"><a href="https://dashboard.default-tenant.app.bh-eks-demo4.aws.bentlyconnect.com/mlprojects/git-proj-vivek/jobs/monitor/3888d4f600ae4d95a252dca82830b626/overview" target="_blank" >...2830b626</a></div></td>
#       <td>0</td>
#       <td>Jun 29 09:00:11</td>
#       <td>completed</td>
#       <td>ad_model_training-train_ad_model</td>
#       <td><div class="dictlist">v3io_user=vivek</div><div class="dictlist">kind=local</div><div class="dictlist">owner=vivek</div><div class="dictlist">host=jupyter-vivek-86d5944f5b-qxvpt</div></td>
#       <td></td>
#       <td><div class="dictlist">insightpak_name=ad_model</div><div class="dictlist">instance_id=e1ba6dcc-f789-11ec-9833-c77e004c828c</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/git-proj-vivek/artifacts/">ad_model_e1ba6dcc-f789-11ec-9833-c77e004c828c</div><div title="v3io:///projects/git-proj-vivek/artifacts/model/">ad_model_state_e1ba6dcc-f789-11ec-9833-c77e004c828c</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result888f0e1a-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result888f0e1a-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result888f0e1a" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result888f0e1a-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.bh-eks-demo4.aws.bentlyconnect.com/mlprojects/git-proj-vivek/jobs/monitor/3888d4f600ae4d95a252dca82830b626/overview" target="_blank">click here</a> to open in UI</b>
# > 2022-06-29 09:00:12,991 [info] run executed, status=completed

# %% [markdown]
# ### Running over the cluster
#
# In order to execute or deploy functions on the cluster you need to make sure all the code (context) is accesible to the function container.
# MLRun supports several mechanisms for this:
# 1. Load the code from the archive (Git, zip, tar, share) into the container at runtime
# 2. Clone the code from the archive (Git, zip, tar, share) into the container image (at build time)
# 3. Place the code on a shared volume (e.g. NFS, v3io) and mount it into the function container
#
# > the real-time `nuclio` and `serving` runtimes only support option 2
#
# MLRun will use the archive source url specified in the `load_project()` method. You can update it using the `set_source()` method.
#
# the `pull_at_runtime` flag will determine if the code is loaded in runtime or added to the image during build. the first (at runtime) option is better for debugging while the secound is better for production. Note that if you choose the 2nd option you'll need to build the function before run.

# %%
project.set_source(git_source, pull_at_runtime=True)

# %%
run = project.run_function("ad_model_training")
# Out:
# > 2022-06-29 09:00:40,904 [info] starting run ad_model_training-train_ad_model uid=1caea046a6ec4e4bac31b76ae6cb995f DB=http://mlrun-api:8080
# > 2022-06-29 09:00:41,092 [info] Job is running in the background, pod: ad-model-training-train-ad-model-7x9lr
# Traceback (most recent call last):
#   File "/usr/local/bin/mlrun", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.7/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.7/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.7/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.7/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/site-packages/mlrun/__main__.py", line 365, in run
#     runobj, watch=watch, schedule=schedule, local=local, auto_build=auto_build
#   File "/usr/local/lib/python3.7/site-packages/mlrun/runtimes/base.py", line 419, in run
#     self._pre_run(run, execution)  # hook for runtime specific prep
#   File "/usr/local/lib/python3.7/site-packages/mlrun/runtimes/local.py", line 259, in _pre_run
#     secrets=execution._secrets_manager,
#   File "/usr/local/lib/python3.7/site-packages/mlrun/utils/clones.py", line 127, in extract_source
#     raise ValueError(f"unsupported source format/path {source}")
# ValueError: unsupported source format/path https://github.com/vivekcherarajan1992/anomalydetection.git#main
# final state: error
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>git-proj-vivek</td>
#       <td><div title="1caea046a6ec4e4bac31b76ae6cb995f"><a href="https://dashboard.default-tenant.app.bh-eks-demo4.aws.bentlyconnect.com/mlprojects/git-proj-vivek/jobs/monitor/1caea046a6ec4e4bac31b76ae6cb995f/overview" target="_blank" >...e6cb995f</a></div></td>
#       <td>0</td>
#       <td>Jun 29 09:00:44</td>
#       <td><div style="color: red;" title="">error</div></td>
#       <td>ad_model_training-train_ad_model</td>
#       <td><div class="dictlist">v3io_user=vivek</div><div class="dictlist">kind=job</div><div class="dictlist">owner=vivek</div><div class="dictlist">mlrun/client_version=1.0.2</div></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result41f63b63-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result41f63b63-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result41f63b63" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result41f63b63-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.bh-eks-demo4.aws.bentlyconnect.com/mlprojects/git-proj-vivek/jobs/monitor/1caea046a6ec4e4bac31b76ae6cb995f/overview" target="_blank">click here</a> to open in UI</b>
# > 2022-06-29 09:00:47,376 [info] run executed, status=error
# runtime error: None
# ---------------------------------------------------------------------------
# RunError                                  Traceback (most recent call last)
# <ipython-input-32-ae5df7676bcf> in <module>
# ----> 1 run = project.run_function("ad_model_training")
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/projects/project.py in run_function(self, function, handler, name, params, hyperparams, hyper_param_options, inputs, outputs, workdir, labels, base_task, watch, local, verbose, selector, auto_build)
#    1961             selector=selector,
#    1962             project_object=self,
# -> 1963             auto_build=auto_build,
#    1964         )
#    1965
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/projects/operations.py in run_function(function, handler, name, params, hyperparams, hyper_param_options, inputs, outputs, workdir, labels, base_task, watch, local, verbose, selector, project_object, auto_build)
#     149             local=local,
#     150             artifact_path=pipeline_context.workflow_artifact_path,
# --> 151             auto_build=auto_build,
#     152         )
#     153         if run_result:
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/runtimes/base.py in run(self, runspec, handler, name, project, params, inputs, out_path, workdir, artifact_path, watch, schedule, hyperparams, hyper_param_options, verbose, scrape_metrics, local, local_code_path, auto_build)
#     407         # execute the job remotely (to a k8s cluster via the API service)
#     408         if self._use_remote_api():
# --> 409             return self._submit_job(run, schedule, db, watch)
#     410
#     411         elif self._is_remote and not self._is_api_server and not self.kfp:
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/runtimes/base.py in _submit_job(self, runspec, schedule, db, watch)
#     684                 result = self._update_run_state(task=runspec, err=err)
#     685             return self._wrap_run_result(result, runspec, schedule=schedule, err=err)
# --> 686         return self._wrap_run_result(resp, runspec, schedule=schedule)
#     687
#     688     def _store_function(self, runspec, meta, db):
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/runtimes/base.py in _wrap_run_result(self, result, runspec, schedule, err)
#     497                 if self._is_remote and not self.is_child:
#     498                     print(f"runtime error: {run.status.error}")
"ts": 1577868600.0, "val": 43.0}, {"ts": 1577868900.0, "val": 69.0}, {"ts": 1577869200.0, "val": 3.0}, {"ts": 1577869800.0, "val": 90.0}, {"ts": 1577870100.0, "val": 50.0}, {"ts": 1577870400.0, "val": 2.0}, {"ts": 1577871300.0, "val": 74.0}, {"ts": 1577871600.0, "val": 41.0}, {"ts": 1577871900.0, "val": 81.0}, {"ts": 1577872200.0, "val": 37.0}, {"ts": 1577872800.0, "val": 79.0}, {"ts": 1577873100.0, "val": 46.0}, {"ts": 1577873400.0, "val": 80.0}, {"ts": 1577873700.0, "val": 30.0}, {"ts": 1577874000.0, "val": 57.0}, {"ts": 1577874300.0, "val": 39.0}, {"ts": 1577874600.0, "val": 6.0}, {"ts": 1577874900.0, "val": 25.0}, {"ts": 1577875500.0, "val": 15.0}, {"ts": 1577876100.0, "val": 66.0}, {"ts": 1577876700.0, "val": 48.0}, {"ts": 1577877000.0, "val": 64.0}, {"ts": 1577877300.0, "val": 24.0}, {"ts": 1577877600.0, "val": 18.0}, {"ts": 1577877900.0, "val": 41.0}, {"ts": 1577878500.0, "val": 5.0}, {"ts": 1577878800.0, "val": 85.0}, {"ts": ...
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/projects/project.py in deploy_function(self, function, dashboard, models, env, tag, verbose, builder_env)
#    2030             verbose=verbose,
#    2031             builder_env=builder_env,
# -> 2032             project_object=self,
#    2033         )
#    2034
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/projects/operations.py in deploy_function(function, dashboard, models, env, tag, verbose, builder_env, project_object)
#     296                 function.add_model(**model_args)
#     297         address = function.deploy(
# --> 298             dashboard=dashboard, tag=tag, verbose=verbose, builder_env=builder_env
#     299         )
#     300         # return object with the same outputs as the KFP op (allow using the same pipeline)
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/runtimes/serving.py in deploy(self, dashboard, project, tag, verbose, auth_info, builder_env)
#     574
#     575         return super().deploy(
# --> 576             dashboard, project, tag, verbose, auth_info, builder_env=builder_env
#     577         )
#     578
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/runtimes/function.py in deploy(self, dashboard, project, tag, verbose, auth_info, builder_env)
#     574             data = db.remote_builder(self, False, builder_env=builder_env)
#     575             self.status = data["data"].get("status")
# --> 576             self._wait_for_function_deployment(db, verbose=verbose)
#     577
#     578             # NOTE: on older mlrun versions & nuclio versions, function are exposed via NodePort
#
# ~/.pythonlibs/jupyter-vivek/lib/python3.7/site-packages/mlrun/runtimes/function.py in _wait_for_function_deployment(self, db, verbose)
#     644         if state != "ready":
#     645             logger.error("Nuclio function failed to deploy", function_state=state)
# --> 646             raise RunError(f"function {self.metadata.name} deployment failed")
#     647
#     648     @min_nuclio_versions("1.5.20", "1.6.10")
#
# RunError: function serving deployment failed

# %% [markdown]
# [**Back to top**](#top)
